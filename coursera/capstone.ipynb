# %% [markdown]
# # IBM Applied Data Science Capstone Project

# %% [markdown]
# ## Table of contents
# 1. [Introduction](#introduction)
# 2. [Data](#data)
# 3. [Methodology](#methodology)
# 4. [Analysis](#analysis)
# 5. [Results and Conclusion](#results)

# %% [markdown]
# ## 1. Introduction <a name="introduction"></a>

# %% [markdown]
# ### 1.1 Business problem

# %% [markdown]
# Every big city such as **New York**, **Berlin** or even **Moscow** is huge and multicultural. People that living and working there coming from all around the world. They have differencies not only in culture, but in beliefs as well. What can make happy some can insult the others. Therefore, the customers interests in products could be very different.
#
# Another call to businesses dropped by the well-off level of the citizens. The amplitude of wealth in these cities is covering all possible ranges. It can happen that people in some districts would be too rich for standart grade product and willing to have only the premium one, while in other the poverty level will motivate the people to make saving every single cent.
#
# Additionally to that here many other factors that should be taken in mind: the citizens age, city criminal activity rate, city financial sources, the temperature and weather data, geographical potential and many others.
#
# So for some specific business (e.g. network cloth store like H&M) it could be easy to find a good spot for opening another shop for their branch. Meanwhile for some others (e.g. coffee shop, newspaper stand, small grocery, etc) it would be not a trivial task without conducted research.

# %% [markdown]
# ### 1.2 Choosen one to be solved

# %% [markdown]
# So in this research we are presuming that we or our customer is a startup company, which buisness is the bike sharing. Bike sharing business is getting more and more popular each year. Hence, there are many competitors in this field. As a start-up we can't afford to place stations randomly in every city neighborhood. This way we have to find the best starting region and possible regions for later expand of our business. In this case we will analyse the biggest city in **Canada - Toronto**, which by the way comfortably located on the south of the country and that making biking there more suitable.

# %% [markdown]
# ## 2. Data <a name="data"></a>

# %% [markdown]
# ### 2.1 Data sources

# %% [markdown]
# To do this research we have to define which kinds of data we need to analyse the current situation.
#
# First of all we must take in a count the security aspect to not ruin the business in first few hours with a bunch of accidents and bike thefts. Therefore we must have the data about crime activities and accidents in the city.
#
# For collecting **_The accident data_** in this city we will be using the next datasets provided by the [Toronto Police Service](http://data.torontopolice.on.ca/):
#
# * [Accidents involving cyclists, where people got Killed or became Seriously Injured in a period 2007-2017](http://data.torontopolice.on.ca/datasets/55d5b9f7af7d4710bc98743b2c005f02_0)
# * [Bicycle Thefts in period 2014-2017](http://data.torontopolice.on.ca/datasets/16f2b8a1c76547c69fec14b7f8541ffc_0)
#
# The next what we have to care about is potential customers. We must collect and process the data about neigborhoods population to get know their commuting tastes. That information will help us to find out which areas are more in need of our services.
#
# For collecting **_The neigborhoods demographic information_** we will be using data from the [City of Toronto Open Data Portal](https://www.toronto.ca/ext/open_data/catalog/data_set_files/2016_neighbourhood_profiles.csv)

# %% [markdown]
# ### 2.2 Data preparation

# %% [markdown]
# First we are loading datasets for pre-processing and improrting necessary libraries.
#
# **Note:** In case if you don't have the libraries used in this project but want to run the code please uncoment corresponding lines to install them

# %%
#!pip install folium
#!pip install bs4
#!pip install opencage
#!pip install foursquare


import numpy as np
import pandas as pd

from bs4 import BeautifulSoup
import requests
import foursquare
from opencage.geocoder import OpenCageGeocode

from time import sleep
from IPython.display import display
import folium

park_out = pd.read_csv("Bicycle Parking Map Data.csv") 
park_in = pd.read_csv("Bicycle Parking Data - Indoor.csv") 
thefts = pd.read_csv("Bicycle_Thefts.csv") 
incidents = pd.read_csv("Cyclists.csv") 
profiles = pd.read_csv("2016_neighbourhood_profiles.csv", encoding='iso-8859-1')

# %% [markdown]
# We will start pre-processing with the datasets related to the security aspects. Therefore let's take a look on the thefts and incidents datasets.

# %%
print ("Thefts:")
thefts.columns.values
# Out:
# Thefts:
# array(['X', 'Y', 'Index_', 'event_unique_id', 'Primary_Offence',
#        'Occurrence_Date', 'Occurrence_Year', 'Occurrence_Month',
#        'Occurrence_Day', 'Occurrence_Time', 'Division', 'City',
#        'Location_Type', 'premisetype', 'Bike_Make', 'Bike_Model',
#        'Bike_Type', 'Bike_Speed', 'Bike_Colour', 'Cost_of_Bike', 'Status',
#        'Hood_ID', 'Neighbourhood', 'Lat', 'Long', 'ObjectId'],
#       dtype=object)

# %% [markdown]
# We will omit the details about bike parameters and the status of the crime. As well we will exclude any data about the time of the event occurence. Identificator fields such as event_uniqie_id, objectId, hood_id and division are not making any sense for us too. The fields X and Y are duplicating the longitude and latitude information, so we are getting rid of them. For reason that all the crimes were made in the Toronto we do not need the city field. Therefore the only information we are lefting there:
# * Neighbourhood
# * Longitude (X)
# * Latitude (Y)
# * Primary Offence
#
# Unfortunately the aviable data in the dataset taking in account only 2014-2017. So we will left the statistics only for 2017, so it will be more close to today reality in 2019!
#
# It would be good for buisness to reduce chance that our bikes will be stolen and buying only the "safe" ones. So let's make another dataframe from this dataset to see what types of bikes mostly suits to the thief's tastes. Therefore we will create new dataframe **"thief_taste"** and include in it next columns:
# * Bike Make
# * Bike Model
# * Bike Type
# * Bike Colour
# * Cost of Bike
#
# We have a lot of unknown vehicles here, so we are dropping this results from our dataframe.

# %%
theft = thefts[['X', 'Y', 'Neighbourhood', 'Primary_Offence']]
theft.tail(10)
# Out:
#                X          Y                             Neighbourhood  \
# 14270 -79.373062  43.642483    Waterfront Communities-The Island (77)
# 14271 -79.413139  43.663345              Palmerston-Little Italy (80)
# 14272 -79.429436  43.661152  Dovercourt-Wallace Emerson-Junction (93)
# 14273 -79.402710  43.666908                                Annex (95)
# 14274 -79.423355  43.790058                     Newtonbrook West (36)
# 14275 -79.423775  43.713600                 Bedford Park-Nortown (39)
# 14276 -79.534058  43.619293           Islington-City Centre West (14)
# 14277 -79.390793  43.649132    Waterfront Communities-The Island (77)
# 14278 -79.383110  43.661373                Church-Yonge Corridor (75)
# 14279 -79.455894  43.665840  Dovercourt-Wallace Emerson-Junction (93)
#
#              Primary_Offence
# 14270                    B&E
# 14271            THEFT UNDER
# 14272            THEFT UNDER
# 14273  THEFT UNDER - BICYCLE
# 14274  THEFT UNDER - BICYCLE
# 14275  THEFT UNDER - BICYCLE
# 14276            THEFT UNDER
# 14277            THEFT UNDER
# 14278  THEFT UNDER - BICYCLE
# 14279  THEFT UNDER - BICYCLE

# %%
thief_taste = thefts[['Bike_Make', 'Bike_Model', 'Bike_Type', 'Bike_Colour', 'Cost_of_Bike']]
thief_taste = thief_taste[thief_taste.Bike_Make != 'UNKNOWN']
thief_taste.tail(10)
# Out:
#              Bike_Make       Bike_Model Bike_Type Bike_Colour Cost_of_Bike
# 14270  KH               URBAN SOUL             RG      BLK             525
# 14271  NO               PINNACLE               MT      GRY             300
# 14272  KO               DEW                    RG      BLK             700
# 14273  CA               CANNONDALE             TO      WHI            1000
# 14274  RA               HYBRID                 RG      GRN             350
# 14275  OT               STUMPJUMPER FSR        MT      BLK            2500
# 14276  RM                           NaN        MT      RED            1000
# 14277  IH                           NaN        MT      DGR               0
# 14278  PR                           NaN        MT      PLE             150
# 14279  BI                           NaN        TO      GRN             500

# %%
print ("Incidents:")
incidents.columns.values
# Out:
# Incidents:
# array(['X', 'Y', 'Index_', 'ACCNUM', 'YEAR', 'DATE', 'TIME', 'Hour',
#        'STREET1', 'STREET2', 'OFFSET', 'ROAD_CLASS', 'District',
#        'LATITUDE', 'LONGITUDE', 'LOCCOORD', 'ACCLOC', 'TRAFFCTL',
#        'VISIBILITY', 'LIGHT', 'RDSFCOND', 'ACCLASS', 'IMPACTYPE',
#        'INVTYPE', 'INVAGE', 'INJURY', 'FATAL_NO', 'INITDIR', 'VEHTYPE',
#        'MANOEUVER', 'DRIVACT', 'DRIVCOND', 'PEDTYPE', 'PEDACT', 'PEDCOND',
#        'CYCLISTYPE', 'CYCACT', 'CYCCOND', 'PEDESTRIAN', 'CYCLIST',
#        'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_', 'EMERG_VEH',
#        'PASSENGER', 'SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL',
#        'DISABILITY', 'Division', 'Ward_Name', 'Ward_ID', 'Hood_ID',
#        'Hood_Name', 'FID'], dtype=object)

# %% [markdown]
# In the incidents dataset we are interested only in coordinates where event happen, injury level and the neighbourhood name. Therefore we will use the next information in our dataframe:
# * Longitude (X)
# * Latitude (Y)
# * Neighbourhood
# * Injury

# %%
incid = incidents[['X', 'Y', 'Hood_Name', 'INJURY']]
incid.rename(columns={'Hood_Name':'Neighbourhood', 'INJURY': 'Injury'}, inplace=True)

incid.head(10)
# Out:
#            X          Y        Neighbourhood   Injury
# 0 -79.366696  43.659267       Moss Park (73)    Major
# 1 -79.366696  43.659267       Moss Park (73)     None
# 2 -79.366696  43.659267       Moss Park (73)     None
# 3 -79.366696  43.659267       Moss Park (73)     None
# 4 -79.366696  43.659267       Moss Park (73)    Major
# 5 -79.439961  43.650940  Dufferin Grove (83)     None
# 6 -79.439961  43.650940  Dufferin Grove (83)    Major
# 7 -79.439961  43.650940  Dufferin Grove (83)     None
# 8 -79.443990  43.658045  Dufferin Grove (83)  Minimal
# 9 -79.443990  43.658045  Dufferin Grove (83)     None

# %%
print("Profiles output")
profiles.head(10)
# Out:
# Profiles output
#                     Category                      Topic  \
# 0  Neighbourhood Information  Neighbourhood Information
# 1  Neighbourhood Information  Neighbourhood Information
# 2                 Population   Population and dwellings
# 3                 Population   Population and dwellings
# 4                 Population   Population and dwellings
# 5                 Population   Population and dwellings
# 6                 Population   Population and dwellings
# 7                 Population   Population and dwellings
# 8                 Population   Population and dwellings
# 9                 Population        Age characteristics
#
#                       Data Source  \
# 0                 City of Toronto
# 1                 City of Toronto
# 2  Census Profile 98-316-X2016001
# 3  Census Profile 98-316-X2016001
# 4  Census Profile 98-316-X2016001
# 5  Census Profile 98-316-X2016001
# 6  Census Profile 98-316-X2016001
# 7  Census Profile 98-316-X2016001
# 8  Census Profile 98-316-X2016001
# 9  Census Profile 98-316-X2016001
#
#                                   Characteristic City of Toronto  \
# 0                           Neighbourhood Number             NaN
# 1                           TSNS2020 Designation             NaN
# 2                               Population, 2016       2,731,571
# 3                               Population, 2011       2,615,060
# 4                    Population Change 2011-2016           4.50%
# 5                        Total private dwellings       1,179,057
# 6  Private dwellings occupied by usual residents       1,112,929
# 7        Population density per square kilometre           4,334
# 8                 Land area in square kilometres           630.2
# 9                          Children (0-14 years)         398,135
#
#   Agincourt North Agincourt South-Malvern West       Alderwood  \
# 0             129                          128              20
# 1  No Designation               No Designation  No Designation
# 2          29,113                       23,757          12,054
# 3          30,279                       21,988          11,904
# 4          -3.90%                        8.00%           1.30%
# 5           9,371                        8,535           4,732
# 6           9,120                        8,136           4,616
# 7           3,929                        3,034           2,435
# 8            7.41                         7.83            4.95
# 9           3,840                        3,075           1,760
#
#             Annex Banbury-Don Mills           ...           Willowdale West  \
# 0              95                42           ...                        37
# 1  No Designation    No Designation           ...            No Designation
# 2          30,526            27,695           ...                    16,936
# 3          29,177            26,918           ...                    15,004
# 4           4.60%             2.90%           ...                    12.90%
# 5          18,109            12,473           ...                     8,054
# 6          15,934            12,124           ...                     7,549
# 7          10,863             2,775           ...                     5,820
# 8            2.81              9.98           ...                      2.91
# 9           2,360             3,605           ...                     1,785
#
#   Willowridge-Martingrove-Richview  Woburn Woodbine Corridor Woodbine-Lumsden  \
# 0                                7     137                64               60
# 1                   No Designation     NIA    No Designation   No Designation
# 2                           22,156  53,485            12,541            7,865
# 3                           21,343  53,350            11,703            7,826
# 4                            3.80%   0.30%             7.20%            0.50%
# 5                            8,721  19,098             5,620            3,604
# 6                            8,509  18,436             5,454            3,449
# 7                            4,007   4,345             7,838            6,722
# 8                             5.53   12.31               1.6             1.17
# 9                            3,555   9,625             2,325            1,165
#
#          Wychwood  Yonge-Eglinton  Yonge-St.Clair York University Heights  \
# 0              94             100              97                      27
# 1  No Designation  No Designation  No Designation                     NIA
# 2          14,349          11,817          12,528                  27,593
# 3          13,986          10,578          11,652                  27,713
# 4           2.60%          11.70%           7.50%                  -0.40%
# 5           6,185           6,103           7,475                  11,051
# 6           5,887           5,676           7,012                  10,170
# 7           8,541           7,162          10,708                   2,086
# 8            1.68            1.65            1.17                   13.23
# 9           1,860           1,800           1,210                   4,045
#
#        Yorkdale-Glen Park
# 0                      31
# 1  Emerging Neighbourhood
# 2                  14,804
# 3                  14,687
# 4                   0.80%
# 5                   5,847
# 6                   5,344
# 7                   2,451
# 8                    6.04
# 9                   1,960
#
# [10 rows x 145 columns]

# %% [markdown]
# As we can see that's massive dataset that providing the information about all neigborhoods in the city. Let's take a look closer what demographic data we can take and use out of here.

# %%
profiles["Topic"].unique()
# Out:
# array(['Neighbourhood Information', 'Population and dwellings',
#        'Age characteristics', 'Household and dwelling characteristics',
#        'Marital status', 'Family characteristics', 'Household type',
#        'Family characteristics of adults',
#        'Knowledge of official languages',
#        'First official language spoken', 'Mother tongue',
#        'Language spoken most often at home',
#        'Other language spoken regularly at home',
#        'Knowledge of languages', 'Income of individuals in 2015',
#        'Income of households in 2015',
#        'Income of economic families in 2015', 'Low income in 2015',
#        'Citizenship', 'Immigrant status and period of immigration',
#        'Age at immigration', 'Immigrants by selected place of birth',
#        'Recent immigrants by selected place of birth',
#        'Generation status', 'Admission category and applicant type',
#        'Aboriginal population', 'Visible minority population',
#        'Ethnic origin population', 'Household characteristics',
#        'Core housing need', 'Highest certificate, diploma or degree',
#        'Major field of study - Classification of Instructional Programs (CIP) 2016',
#        'Location of study compared with province or territory of residence with countries outside Canada',
#        'Labour force status', 'Work activity during the reference year',
#        'Class of worker',
#        'Occupation - National Occupational Classification (NOC) 2016',
#        'Industry - North American Industry Classification System (NAICS) 2012',
#        'Place of work status', 'Commuting destination',
#        'Main mode of commuting', 'Commuting duration',
#        'Time leaving for work', 'Language used most often at work',
#        'Other language used regularly at work', 'Income sources',
#        'Income taxes', 'Mobility status - Place of residence 1 year ago',
#        'Mobility status - Place of residence 5 years ago'], dtype=object)

# %% [markdown]
# We will select next categories in column topics for our research **'Neighbourhood Information', 'Age characteristics', 'Commuting destination', 'Main mode of commuting', 'Commuting duration'.**
# The columns **'Category', 'Data Soruce', 'City of Toronto'** have no valuable information for us, so we will exclude these columns from our dataframes. The column **'Topic'** have to be excluded as well but we will do it after splitting dataset into required dataframes.

# %%
profiles.drop('Data Source', axis=1, inplace=True)
profiles.drop('Category', axis=1, inplace=True)
profiles.drop('City of Toronto', axis=1, inplace=True)

demo_age = profiles[profiles.Topic == 'Age characteristics']
demo_age.drop('Topic', axis=1, inplace=True)

demo_cdes = profiles[profiles.Topic == 'Commuting destination']
demo_cdes.drop('Topic', axis=1, inplace=True)

demo_mmoc = profiles[profiles.Topic == 'Main mode of commuting']
demo_mmoc.drop('Topic', axis=1, inplace=True)

demo_cdur = profiles[profiles.Topic == 'Commuting duration']
demo_cdur.drop('Topic', axis=1, inplace=True)

demo_age.head(10)
# Out:
#                   Characteristic Agincourt North Agincourt South-Malvern West  \
# 9          Children (0-14 years)           3,840                        3,075
# 10           Youth (15-24 years)           3,705                        3,360
# 11     Working Age (25-54 years)          11,305                        9,965
# 12  Pre-retirement (55-64 years)           4,230                        3,265
# 13           Seniors (65+ years)           6,045                        4,105
# 14     Older Seniors (85+ years)             925                          555
# 15           Male: 0 to 04 years             660                          575
# 16          Male: 05 to 09 years             695                          540
# 17          Male: 10 to 14 years             660                          460
# 18          Male: 15 to 19 years             840                          780
#
#    Alderwood   Annex Banbury-Don Mills Bathurst Manor Bay Street Corridor  \
# 9      1,760   2,360             3,605          2,325               1,695
# 10     1,235   3,750             2,730          1,940               6,860
# 11     5,220  15,040            10,810          6,655              13,065
# 12     1,825   3,480             3,555          2,030               1,760
# 13     2,015   5,910             6,975          2,940               2,420
# 14       320   1,040             1,640            710                 330
# 15       360     445               570            435                 470
# 16       270     365               660            355                 230
# 17       225     325               675            415                 130
# 18       285     465               715            490                 585
#
#    Bayview Village Bayview Woods-Steeles        ...         Willowdale West  \
# 9            2,415                 1,515        ...                   1,785
# 10           2,505                 1,635        ...                   2,230
# 11          10,310                 4,490        ...                   7,480
# 12           2,540                 1,825        ...                   2,070
# 13           3,615                 3,685        ...                   3,370
# 14             610                   740        ...                     655
# 15             455                   205        ...                     355
# 16             395                   260        ...                     310
# 17             410                   320        ...                     265
# 18             520                   385        ...                     415
#
#    Willowridge-Martingrove-Richview  Woburn Woodbine Corridor  \
# 9                             3,555   9,625             2,325
# 10                            2,625   7,660             1,035
# 11                            8,140  21,945             6,165
# 12                            2,905   6,245             1,625
# 13                            4,905   8,010             1,380
# 14                              885   1,130               170
# 15                              620    1625               460
# 16                              625    1705               400
# 17                              610    1600               330
# 18                              680    1815               275
#
#    Woodbine-Lumsden Wychwood Yonge-Eglinton Yonge-St.Clair  \
# 9             1,165    1,860          1,800          1,210
# 10              675    1,320          1,225            920
# 11            3,790    6,420          5,860          5,960
# 12            1,150    1,595          1,325          1,540
# 13            1,095    3,150          1,600          2,905
# 14              125      880            165            470
# 15              225      325            300            220
# 16              180      350            305            220
# 17              180      310            280            195
# 18              160      260            255            145
#
#    York University Heights Yorkdale-Glen Park
# 9                    4,045              1,960
# 10                   4,750              1,870
# 11                  12,290              5,860
# 12                   2,965              1,810
# 13                   3,530              3,295
# 14                     400                775
# 15                     755                320
# 16                     685                315
# 17                     635                370
# 18                     900                485
#
# [10 rows x 141 columns]

# %% [markdown]
# In the age dataframe we do not need distinguishing between the genders, so we will left only first 5 rows with the united data from both genders

# %%
demo_age = demo_age[:5]

# %% [markdown]
# Let's reindex the rows by 'Characteristic' value

# %%
demo_age = demo_age.set_index('Characteristic')
demo_cdes = demo_cdes.set_index('Characteristic')
demo_mmoc = demo_mmoc.set_index('Characteristic')
demo_cdur = demo_cdur.set_index('Characteristic')

demo_cdur.head()
# Out:
#                                                    Agincourt North  \
# Characteristic
# Total - Commuting duration for the employed lab...          11,820
#   Less than 15 minutes                                       1,610
#   15 to 29 minutes                                           3,175
#   30 to 44 minutes                                           2,940
#   45 to 59 minutes                                           1,410
#
#                                                    Agincourt South-Malvern West  \
# Characteristic
# Total - Commuting duration for the employed lab...                       10,155
#   Less than 15 minutes                                                    1,455
#   15 to 29 minutes                                                        2,735
#   30 to 44 minutes                                                        2,515
#   45 to 59 minutes                                                        1,230
#
#                                                    Alderwood   Annex  \
# Characteristic
# Total - Commuting duration for the employed lab...     6,045  14,905
#   Less than 15 minutes                                 1,210   2,330
#   15 to 29 minutes                                     1,815   6,260
#   30 to 44 minutes                                     1,495   4,000
#   45 to 59 minutes                                       630   1,410
#
#                                                    Banbury-Don Mills  \
# Characteristic
# Total - Commuting duration for the employed lab...            11,395
#   Less than 15 minutes                                         1,695
#   15 to 29 minutes                                             3,475
#   30 to 44 minutes                                             3,110
#   45 to 59 minutes                                             1,540
#
#                                                    Bathurst Manor  \
# Characteristic
# Total - Commuting duration for the employed lab...          7,355
#   Less than 15 minutes                                        850
#   15 to 29 minutes                                          1,750
#   30 to 44 minutes                                          2,120
#   45 to 59 minutes                                          1,465
#
#                                                    Bay Street Corridor  \
# Characteristic
# Total - Commuting duration for the employed lab...              11,815
#   Less than 15 minutes                                           3,175
#   15 to 29 minutes                                               4,900
#   30 to 44 minutes                                               2,200
#   45 to 59 minutes                                                 690
#
#                                                    Bayview Village  \
# Characteristic
# Total - Commuting duration for the employed lab...           9,820
#   Less than 15 minutes                                         860
#   15 to 29 minutes                                           2,560
#   30 to 44 minutes                                           3,065
#   45 to 59 minutes                                           1,865
#
#                                                    Bayview Woods-Steeles  \
# Characteristic
# Total - Commuting duration for the employed lab...                 4,965
#   Less than 15 minutes                                               480
#   15 to 29 minutes                                                 1,385
#   30 to 44 minutes                                                 1,320
#   45 to 59 minutes                                                   770
#
#                                                    Bedford Park-Nortown  \
# Characteristic
# Total - Commuting duration for the employed lab...                9,515
#   Less than 15 minutes                                            1,560
#   15 to 29 minutes                                                3,060
#   30 to 44 minutes                                                2,995
#   45 to 59 minutes                                                1,200
#
#                                                           ...          \
# Characteristic                                            ...
# Total - Commuting duration for the employed lab...        ...
#   Less than 15 minutes                                    ...
#   15 to 29 minutes                                        ...
#   30 to 44 minutes                                        ...
#   45 to 59 minutes                                        ...
#
#                                                    Willowdale West  \
# Characteristic
# Total - Commuting duration for the employed lab...           6,890
#   Less than 15 minutes                                         680
#   15 to 29 minutes                                           1,680
#   30 to 44 minutes                                           2,200
#   45 to 59 minutes                                           1,290
#
#                                                    Willowridge-Martingrove-Richview  \
# Characteristic
# Total - Commuting duration for the employed lab...                            9,365
#   Less than 15 minutes                                                        1,155
#   15 to 29 minutes                                                            3,165
#   30 to 44 minutes                                                            2,320
#   45 to 59 minutes                                                            1,170
#
#                                                     Woburn Woodbine Corridor  \
# Characteristic
# Total - Commuting duration for the employed lab...  21,595             5,965
#   Less than 15 minutes                               2,740               530
#   15 to 29 minutes                                   5,360             1,450
#   30 to 44 minutes                                   5,280             2,145
#   45 to 59 minutes                                   2,895             1,095
#
#                                                    Woodbine-Lumsden Wychwood  \
# Characteristic
# Total - Commuting duration for the employed lab...            4,095    6,590
#   Less than 15 minutes                                          370      585
#   15 to 29 minutes                                              900    2,020
#   30 to 44 minutes                                            1,420    2,355
#   45 to 59 minutes                                              915      915
#
#                                                    Yonge-Eglinton  \
# Characteristic
# Total - Commuting duration for the employed lab...          5,935
#   Less than 15 minutes                                        695
#   15 to 29 minutes                                          1,765
#   30 to 44 minutes                                          2,215
#   45 to 59 minutes                                            795
#
#                                                    Yonge-St.Clair  \
# Characteristic
# Total - Commuting duration for the employed lab...          6,350
#   Less than 15 minutes                                        780
#   15 to 29 minutes                                          2,265
#   30 to 44 minutes                                          2,195
#   45 to 59 minutes                                            630
#
#                                                    York University Heights  \
# Characteristic
# Total - Commuting duration for the employed lab...                  12,790
#   Less than 15 minutes                                               1,365
#   15 to 29 minutes                                                   3,280
#   30 to 44 minutes                                                   3,430
#   45 to 59 minutes                                                   1,605
#
#                                                    Yorkdale-Glen Park
# Characteristic
# Total - Commuting duration for the employed lab...              6,420
#   Less than 15 minutes                                            850
#   15 to 29 minutes                                              1,770
#   30 to 44 minutes                                              2,170
#   45 to 59 minutes                                                845
#
# [5 rows x 140 columns]

# %% [markdown]
# ## 3. Methodology <a name="methodology"></a>

# %% [markdown]
# In our project we want to find the best neighbourhoods to start our bike sharing business, particularly the safest ones with infrastructure and free bike parking spots. Hence we will first prioritise the analysis parameters:
#
# 1. _Safety_
# 2. _Demographic commute data_
# 3. _Theft security_
#
# In the data section we collected the data about incidents involving cyclists, which happen in different neighbourhoods. This data included the **neighbourhood** name and **injury** level taken by the victim. Basing on this information we can determing the **safety** of regions.
#
# At the end of data preparation section we constructed dataframes with demographic data which includes information about **citizen's age** and their **commute information** in different neighbourhoods. This can help to estimate where our bike sharing services will be most welcomed.
#
# Additionally we will make a small research on which bikes are more likely to be stolen. For this we use the offical data from Toronto Police Service about reported **bike thefts**.

# %% [markdown]
# ## 4. Analysis  <a name="analysis"></a>

# %% [markdown]
# ### 4.1 Safety

# %%
incid.head(10)
# Out:
#            X          Y        Neighbourhood   Injury
# 0 -79.366696  43.659267       Moss Park (73)    Major
# 1 -79.366696  43.659267       Moss Park (73)     None
# 2 -79.366696  43.659267       Moss Park (73)     None
# 3 -79.366696  43.659267       Moss Park (73)     None
# 4 -79.366696  43.659267       Moss Park (73)    Major
# 5 -79.439961  43.650940  Dufferin Grove (83)     None
# 6 -79.439961  43.650940  Dufferin Grove (83)    Major
# 7 -79.439961  43.650940  Dufferin Grove (83)     None
# 8 -79.443990  43.658045  Dufferin Grove (83)  Minimal
# 9 -79.443990  43.658045  Dufferin Grove (83)     None

# %% [markdown]
# Let's count the overall number of the incidents happen in the Toronto by the neigborhoods and select top 10.

# %%
safety = incid['Neighbourhood'].value_counts(sort=True, ascending=True).rename_axis('Neighbourhood').reset_index(name='Incidents')
safety = safety.head(10)
safety
# Out:
#                             Neighbourhood  Incidents
# 0            Palmerston-Little Italy (80)          3
# 1      Agincourt South-Malvern West (128)          3
# 2  Waterfront Communities-The Island (77)          3
# 3                           Wychwood (94)          3
# 4                    Little Portugal (84)          3
# 5                Mount Pleasant East (99)          3
# 6             Birchcliffe-Cliffside (122)          3
# 7                        The Beaches (63)          3
# 8                        New Toronto (18)          3
# 9                          Casa Loma (96)          3

# %% [markdown]
# ### 4.2 Demographic commute data

# %% [markdown]
# #### 4.2.1 Age characteristics

# %%
demo_age
# Out:
#                              Agincourt North Agincourt South-Malvern West  \
# Characteristic
# Children (0-14 years)                  3,840                        3,075
# Youth (15-24 years)                    3,705                        3,360
# Working Age (25-54 years)             11,305                        9,965
# Pre-retirement (55-64 years)           4,230                        3,265
# Seniors (65+ years)                    6,045                        4,105
#
#                              Alderwood   Annex Banbury-Don Mills  \
# Characteristic
# Children (0-14 years)            1,760   2,360             3,605
# Youth (15-24 years)              1,235   3,750             2,730
# Working Age (25-54 years)        5,220  15,040            10,810
# Pre-retirement (55-64 years)     1,825   3,480             3,555
# Seniors (65+ years)              2,015   5,910             6,975
#
#                              Bathurst Manor Bay Street Corridor  \
# Characteristic
# Children (0-14 years)                 2,325               1,695
# Youth (15-24 years)                   1,940               6,860
# Working Age (25-54 years)             6,655              13,065
# Pre-retirement (55-64 years)          2,030               1,760
# Seniors (65+ years)                   2,940               2,420
#
#                              Bayview Village Bayview Woods-Steeles  \
# Characteristic
# Children (0-14 years)                  2,415                 1,515
# Youth (15-24 years)                    2,505                 1,635
# Working Age (25-54 years)             10,310                 4,490
# Pre-retirement (55-64 years)           2,540                 1,825
# Seniors (65+ years)                    3,615                 3,685
#
#                              Bedford Park-Nortown        ...          \
# Characteristic                                           ...
# Children (0-14 years)                       4,555        ...
# Youth (15-24 years)                         3,210        ...
# Working Age (25-54 years)                   8,410        ...
# Pre-retirement (55-64 years)                3,075        ...
# Seniors (65+ years)                         3,980        ...
#
#                              Willowdale West Willowridge-Martingrove-Richview  \
# Characteristic
# Children (0-14 years)                  1,785                            3,555
# Youth (15-24 years)                    2,230                            2,625
# Working Age (25-54 years)              7,480                            8,140
# Pre-retirement (55-64 years)           2,070                            2,905
# Seniors (65+ years)                    3,370                            4,905
#
#                               Woburn Woodbine Corridor Woodbine-Lumsden  \
# Characteristic
# Children (0-14 years)          9,625             2,325            1,165
# Youth (15-24 years)            7,660             1,035              675
# Working Age (25-54 years)     21,945             6,165            3,790
# Pre-retirement (55-64 years)   6,245             1,625            1,150
# Seniors (65+ years)            8,010             1,380            1,095
#
#                              Wychwood Yonge-Eglinton Yonge-St.Clair  \
# Characteristic
# Children (0-14 years)           1,860          1,800          1,210
# Youth (15-24 years)             1,320          1,225            920
# Working Age (25-54 years)       6,420          5,860          5,960
# Pre-retirement (55-64 years)    1,595          1,325          1,540
# Seniors (65+ years)             3,150          1,600          2,905
#
#                              York University Heights Yorkdale-Glen Park
# Characteristic
# Children (0-14 years)                          4,045              1,960
# Youth (15-24 years)                            4,750              1,870
# Working Age (25-54 years)                     12,290              5,860
# Pre-retirement (55-64 years)                   2,965              1,810
# Seniors (65+ years)                            3,530              3,295
#
# [5 rows x 140 columns]

# %% [markdown]
# Our target customer groups are
# 1. Youth (15-24 years)
# 2. Working Age (25-54 years)
#
# Let's find top 10 neigborhoods with thge highest number of the people from these two groups

# %%
demo_age = demo_age[1:3]
demo_age_t = demo_age.T
demo_age_t['Youth (15-24 years)'] = demo_age_t['Youth (15-24 years)'].str.replace(',', '')
demo_age_t['Working Age (25-54 years)'] = demo_age_t['Working Age (25-54 years)'].str.replace(',', '')
demo_age_t[['Youth (15-24 years)', 'Working Age (25-54 years)']] = demo_age_t[['Youth (15-24 years)', 'Working Age (25-54 years)']].astype(int)
demo_age_t['Total'] = demo_age_t.sum(axis = 1)
demo_age_t = demo_age_t.sort_values(by=['Total'], ascending=False)
demo_age_t = demo_age_t.head(10)
demo_age_t
# Out:
# Characteristic                       Youth (15-24 years)  \
# Waterfront Communities-The Island                   7840
# Willowdale East                                     6940
# Woburn                                              7660
# Niagara                                             2415
# Islington-City Centre West                          4695
# Rouge                                               6700
# Malvern                                             6620
# Church-Yonge Corridor                               5060
# Dovercourt-Wallace Emerson-Junction                 3925
# L'Amoreaux                                          5730
#
# Characteristic                       Working Age (25-54 years)  Total
# Waterfront Communities-The Island                        45105  52945
# Willowdale East                                          25850  32790
# Woburn                                                   21945  29605
# Niagara                                                  23320  25735
# Islington-City Centre West                               20640  25335
# Rouge                                                    18510  25210
# Malvern                                                  17865  24485
# Church-Yonge Corridor                                    18780  23840
# Dovercourt-Wallace Emerson-Junction                      19790  23715
# L'Amoreaux                                               17210  22940

# %% [markdown]
# #### 4.2.2 Commuting destination

# %%
demo_cdes
# Out:
#                                                    Agincourt North  \
# Characteristic
# Total - Commuting destination for the employed ...          10,330
#   Commute within census subdivision (CSD) of re...           7,210
#   Commute to a different census subdivision (CS...             NaN
#   Commute to a different census subdivision (CS...           3,095
#   Commute to a different province or territory                  10
#
#                                                    Agincourt South-Malvern West  \
# Characteristic
# Total - Commuting destination for the employed ...                        8,800
#   Commute within census subdivision (CSD) of re...                        6,530
#   Commute to a different census subdivision (CS...                          NaN
#   Commute to a different census subdivision (CS...                        2,240
#   Commute to a different province or territory                               35
#
#                                                    Alderwood   Annex  \
# Characteristic
# Total - Commuting destination for the employed ...     5,155  13,540
#   Commute within census subdivision (CSD) of re...     3,535  12,470
#   Commute to a different census subdivision (CS...       NaN     NaN
#   Commute to a different census subdivision (CS...     1,605   1,025
#   Commute to a different province or territory            10      30
#
#                                                    Banbury-Don Mills  \
# Characteristic
# Total - Commuting destination for the employed ...            10,200
#   Commute within census subdivision (CSD) of re...             8,615
#   Commute to a different census subdivision (CS...               NaN
#   Commute to a different census subdivision (CS...             1,560
#   Commute to a different province or territory                    40
#
#                                                    Bathurst Manor  \
# Characteristic
# Total - Commuting destination for the employed ...          6,250
#   Commute within census subdivision (CSD) of re...          4,810
#   Commute to a different census subdivision (CS...            NaN
#   Commute to a different census subdivision (CS...          1,430
#   Commute to a different province or territory                 15
#
#                                                    Bay Street Corridor  \
# Characteristic
# Total - Commuting destination for the employed ...              10,970
#   Commute within census subdivision (CSD) of re...              10,035
#   Commute to a different census subdivision (CS...                 NaN
#   Commute to a different census subdivision (CS...                 850
#   Commute to a different province or territory                      75
#
#                                                    Bayview Village  \
# Characteristic
# Total - Commuting destination for the employed ...           8,910
#   Commute within census subdivision (CSD) of re...           6,735
#   Commute to a different census subdivision (CS...             NaN
#   Commute to a different census subdivision (CS...           2,130
#   Commute to a different province or territory                  40
#
#                                                    Bayview Woods-Steeles  \
# Characteristic
# Total - Commuting destination for the employed ...                 4,435
#   Commute within census subdivision (CSD) of re...                 3,215
#   Commute to a different census subdivision (CS...                   NaN
#   Commute to a different census subdivision (CS...                 1,185
#   Commute to a different province or territory                        35
#
#                                                    Bedford Park-Nortown  \
# Characteristic
# Total - Commuting destination for the employed ...                8,735
#   Commute within census subdivision (CSD) of re...                7,320
#   Commute to a different census subdivision (CS...                  NaN
#   Commute to a different census subdivision (CS...                1,375
#   Commute to a different province or territory                       40
#
#                                                           ...          \
# Characteristic                                            ...
# Total - Commuting destination for the employed ...        ...
#   Commute within census subdivision (CSD) of re...        ...
#   Commute to a different census subdivision (CS...        ...
#   Commute to a different census subdivision (CS...        ...
#   Commute to a different province or territory            ...
#
#                                                    Willowdale West  \
# Characteristic
# Total - Commuting destination for the employed ...           6,250
#   Commute within census subdivision (CSD) of re...           4,765
#   Commute to a different census subdivision (CS...             NaN
#   Commute to a different census subdivision (CS...           1,450
#   Commute to a different province or territory                  40
#
#                                                    Willowridge-Martingrove-Richview  \
# Characteristic
# Total - Commuting destination for the employed ...                            8,160
#   Commute within census subdivision (CSD) of re...                            5,620
#   Commute to a different census subdivision (CS...                              NaN
#   Commute to a different census subdivision (CS...                            2,535
#   Commute to a different province or territory                                   10
#
#                                                     Woburn Woodbine Corridor  \
# Characteristic
# Total - Commuting destination for the employed ...  18,845             5,350
#   Commute within census subdivision (CSD) of re...  14,935             4,880
#   Commute to a different census subdivision (CS...     NaN               NaN
#   Commute to a different census subdivision (CS...   3,840               460
#   Commute to a different province or territory          70                 0
#
#                                                    Woodbine-Lumsden Wychwood  \
# Characteristic
# Total - Commuting destination for the employed ...            3,580    5,820
#   Commute within census subdivision (CSD) of re...            3,285    5,200
#   Commute to a different census subdivision (CS...              NaN      NaN
#   Commute to a different census subdivision (CS...              290      570
#   Commute to a different province or territory                    0       45
#
#                                                    Yonge-Eglinton  \
# Characteristic
# Total - Commuting destination for the employed ...          5,525
#   Commute within census subdivision (CSD) of re...          4,960
#   Commute to a different census subdivision (CS...            NaN
#   Commute to a different census subdivision (CS...            545
#   Commute to a different province or territory                 15
#
#                                                    Yonge-St.Clair  \
# Characteristic
# Total - Commuting destination for the employed ...          5,810
#   Commute within census subdivision (CSD) of re...          5,325
#   Commute to a different census subdivision (CS...            NaN
#   Commute to a different census subdivision (CS...            470
#   Commute to a different province or territory                 10
#
#                                                    York University Heights  \
# Characteristic
# Total - Commuting destination for the employed ...                  10,885
#   Commute within census subdivision (CSD) of re...                   7,620
#   Commute to a different census subdivision (CS...                     NaN
#   Commute to a different census subdivision (CS...                   3,220
#   Commute to a different province or territory                          40
#
#                                                    Yorkdale-Glen Park
# Characteristic
# Total - Commuting destination for the employed ...              5,400
#   Commute within census subdivision (CSD) of re...              4,340
#   Commute to a different census subdivision (CS...                NaN
#   Commute to a different census subdivision (CS...              1,050
#   Commute to a different province or territory                      0
#
# [5 rows x 140 columns]

# %% [markdown]
# Here we are interested in next category of people Commute within census subdivision (CSD) of residence, so they are not going to take a long trips. Therefore let's find top 10 neighbourhood with the most people from these group of people.

# %%
demo_cdes_t = demo_cdes.T
demo_cdes_t = demo_cdes.T.iloc[:,0:2].drop('Total - Commuting destination for the employed labour force aged 15 years and over in private households with a usual place of work - 25% sample data', axis=1)
demo_cdes_t['  Commute within census subdivision (CSD) of residence'] = demo_cdes_t['  Commute within census subdivision (CSD) of residence'].str.replace(',', '')
demo_cdes_t['  Commute within census subdivision (CSD) of residence'] = demo_cdes_t['  Commute within census subdivision (CSD) of residence'].astype(int)
demo_cdes_t = demo_cdes_t.sort_values(by=['  Commute within census subdivision (CSD) of residence'], ascending=False)
demo_cdes_t = demo_cdes_t.head(10)
demo_cdes_t
# Out:
# Characteristic                         Commute within census subdivision (CSD) of residence
# Waterfront Communities-The Island                                                36345
# Niagara                                                                          16400
# Church-Yonge Corridor                                                            15360
# Willowdale East                                                                  15020
# Woburn                                                                           14935
# Rouge                                                                            14560
# Dovercourt-Wallace Emerson-Junction                                              14285
# Mount Pleasant West                                                              13680
# Islington-City Centre West                                                       13680
# Malvern                                                                          12835

# %% [markdown]
# #### 4.2.3 Main mode of commuting

# %%
demo_mmoc
# Out:
#                                                    Agincourt North  \
# Characteristic
# Total - Main mode of commuting for the employed...          11,820
#   Car, truck, van - as a driver                              7,155
#   Car, truck, van - as a passenger                             930
#   Public transit                                             3,350
#   Walked                                                       265
#   Bicycle                                                       70
#   Other method                                                  45
#
#                                                    Agincourt South-Malvern West  \
# Characteristic
# Total - Main mode of commuting for the employed...                       10,160
#   Car, truck, van - as a driver                                           6,135
#   Car, truck, van - as a passenger                                          665
#   Public transit                                                          2,985
#   Walked                                                                    280
#   Bicycle                                                                    35
#   Other method                                                               65
#
#                                                    Alderwood   Annex  \
# Characteristic
# Total - Main mode of commuting for the employed...     6,045  14,910
#   Car, truck, van - as a driver                        4,090   3,290
#   Car, truck, van - as a passenger                       355     290
#   Public transit                                       1,285   6,200
#   Walked                                                 195   3,200
#   Bicycle                                                 65   1,675
#   Other method                                            65     225
#
#                                                    Banbury-Don Mills  \
# Characteristic
# Total - Main mode of commuting for the employed...            11,395
#   Car, truck, van - as a driver                                7,150
#   Car, truck, van - as a passenger                               500
#   Public transit                                               2,945
#   Walked                                                         615
#   Bicycle                                                         65
#   Other method                                                   140
#
#                                                    Bathurst Manor  \
# Characteristic
# Total - Main mode of commuting for the employed...          7,360
#   Car, truck, van - as a driver                             3,910
#   Car, truck, van - as a passenger                            265
#   Public transit                                            2,870
#   Walked                                                      215
#   Bicycle                                                      15
#   Other method                                                 90
#
#                                                    Bay Street Corridor  \
# Characteristic
# Total - Main mode of commuting for the employed...              11,815
#   Car, truck, van - as a driver                                  1,780
#   Car, truck, van - as a passenger                                 165
#   Public transit                                                 3,540
#   Walked                                                         5,840
#   Bicycle                                                          325
#   Other method                                                     175
#
#                                                    Bayview Village  \
# Characteristic
# Total - Main mode of commuting for the employed...           9,825
#   Car, truck, van - as a driver                              5,270
#   Car, truck, van - as a passenger                             385
#   Public transit                                             3,695
#   Walked                                                       345
#   Bicycle                                                       30
#   Other method                                                 100
#
#                                                    Bayview Woods-Steeles  \
# Characteristic
# Total - Main mode of commuting for the employed...                 4,965
#   Car, truck, van - as a driver                                    2,920
#   Car, truck, van - as a passenger                                   240
#   Public transit                                                   1,610
#   Walked                                                             110
#   Bicycle                                                             10
#   Other method                                                        65
#
#                                                    Bedford Park-Nortown  \
# Characteristic
# Total - Main mode of commuting for the employed...                9,520
#   Car, truck, van - as a driver                                   5,940
#   Car, truck, van - as a passenger                                  355
#   Public transit                                                  2,415
#   Walked                                                            550
#   Bicycle                                                            90
#   Other method                                                      180
#
#                                                           ...          \
# Characteristic                                            ...
# Total - Main mode of commuting for the employed...        ...
#   Car, truck, van - as a driver                           ...
#   Car, truck, van - as a passenger                        ...
#   Public transit                                          ...
#   Walked                                                  ...
#   Bicycle                                                 ...
#   Other method                                            ...
#
#                                                    Willowdale West  \
# Characteristic
# Total - Main mode of commuting for the employed...           6,900
#   Car, truck, van - as a driver                              3,260
#   Car, truck, van - as a passenger                             275
#   Public transit                                             2,845
#   Walked                                                       405
#   Bicycle                                                       55
#   Other method                                                  55
#
#                                                    Willowridge-Martingrove-Richview  \
# Characteristic
# Total - Main mode of commuting for the employed...                            9,360
#   Car, truck, van - as a driver                                               6,220
#   Car, truck, van - as a passenger                                              515
#   Public transit                                                              2,380
#   Walked                                                                        140
#   Bicycle                                                                        20
#   Other method                                                                   65
#
#                                                     Woburn Woodbine Corridor  \
# Characteristic
# Total - Main mode of commuting for the employed...  21,595             5,965
#   Car, truck, van - as a driver                     11,505             2,480
#   Car, truck, van - as a passenger                   1,405               165
#   Public transit                                     7,635             2,540
#   Walked                                               780               340
#   Bicycle                                               45               380
#   Other method                                         210                70
#
#                                                    Woodbine-Lumsden Wychwood  \
# Characteristic
# Total - Main mode of commuting for the employed...            4,100    6,595
#   Car, truck, van - as a driver                               1,685    2,190
#   Car, truck, van - as a passenger                              120      195
#   Public transit                                              1,940    3,005
#   Walked                                                        145      525
#   Bicycle                                                       175      610
#   Other method                                                   30       55
#
#                                                    Yonge-Eglinton  \
# Characteristic
# Total - Main mode of commuting for the employed...          5,935
#   Car, truck, van - as a driver                             1,970
#   Car, truck, van - as a passenger                            155
#   Public transit                                            2,935
#   Walked                                                      635
#   Bicycle                                                     145
#   Other method                                                 90
#
#                                                    Yonge-St.Clair  \
# Characteristic
# Total - Main mode of commuting for the employed...          6,345
#   Car, truck, van - as a driver                             2,050
#   Car, truck, van - as a passenger                            155
#   Public transit                                            3,170
#   Walked                                                      715
#   Bicycle                                                     155
#   Other method                                                 95
#
#                                                    York University Heights  \
# Characteristic
# Total - Main mode of commuting for the employed...                  12,790
#   Car, truck, van - as a driver                                      5,945
#   Car, truck, van - as a passenger                                     665
#   Public transit                                                     5,405
#   Walked                                                               585
#   Bicycle                                                              115
#   Other method                                                          75
#
#                                                    Yorkdale-Glen Park
# Characteristic
# Total - Main mode of commuting for the employed...              6,420
#   Car, truck, van - as a driver                                 3,205
#   Car, truck, van - as a passenger                                355
#   Public transit                                                2,400
#   Walked                                                          360
#   Bicycle                                                          30
#   Other method                                                     85
#
# [7 rows x 140 columns]

# %% [markdown]
# From this dataset we can see the methods how people are commuting in different neighbourhoods. We assume that those who have bicycle already wouldn't be our customers, as well those who driving the car. We are lefting with next categories of people, who identified their main commute method as:
# * Public transit
# * Walked
# * Other method
#
# Now we are going to find top 10 neigborhoods where these methods dominate among the people

# %%
commute = demo_mmoc[3:]
commute_t = commute.T
commute_t = commute_t.drop('  Bicycle', axis=1)

# %%
arr = list(commute_t)
for item in arr:
    commute_t[item] = commute_t[item].str.replace(',', '')
    commute_t[item] = commute_t[item].astype(int) 

commute_t['Total'] = commute_t.sum(axis = 1)
commute_t = commute_t.sort_values(by=['Total'], ascending=False)
commute_t = commute_t.head(10)
commute_t
# Out:
# Characteristic                         Public transit    Walked  \
# Waterfront Communities-The Island               10915     20855
# Church-Yonge Corridor                            7000      7275
# Niagara                                          6965      5070
# Mount Pleasant West                              9435      1840
# Willowdale East                                  9390      1550
# Dovercourt-Wallace Emerson-Junction              8950      1215
# Annex                                            6200      3200
# Bay Street Corridor                              3540      5840
# Islington-City Centre West                       8205       795
# Woburn                                           7635       780
#
# Characteristic                         Other method  Total
# Waterfront Communities-The Island               610  32380
# Church-Yonge Corridor                           190  14465
# Niagara                                         285  12320
# Mount Pleasant West                             100  11375
# Willowdale East                                 215  11155
# Dovercourt-Wallace Emerson-Junction             310  10475
# Annex                                           225   9625
# Bay Street Corridor                             175   9555
# Islington-City Centre West                      195   9195
# Woburn                                          210   8625

# %% [markdown]
# #### 4.2.4 Commuting duration

# %%
demo_cdur
# Out:
#                                                    Agincourt North  \
# Characteristic
# Total - Commuting duration for the employed lab...          11,820
#   Less than 15 minutes                                       1,610
#   15 to 29 minutes                                           3,175
#   30 to 44 minutes                                           2,940
#   45 to 59 minutes                                           1,410
#   60 minutes and over                                        2,670
#
#                                                    Agincourt South-Malvern West  \
# Characteristic
# Total - Commuting duration for the employed lab...                       10,155
#   Less than 15 minutes                                                    1,455
#   15 to 29 minutes                                                        2,735
#   30 to 44 minutes                                                        2,515
#   45 to 59 minutes                                                        1,230
#   60 minutes and over                                                     2,230
#
#                                                    Alderwood   Annex  \
# Characteristic
# Total - Commuting duration for the employed lab...     6,045  14,905
#   Less than 15 minutes                                 1,210   2,330
#   15 to 29 minutes                                     1,815   6,260
#   30 to 44 minutes                                     1,495   4,000
#   45 to 59 minutes                                       630   1,410
#   60 minutes and over                                    895     905
#
#                                                    Banbury-Don Mills  \
# Characteristic
# Total - Commuting duration for the employed lab...            11,395
#   Less than 15 minutes                                         1,695
#   15 to 29 minutes                                             3,475
#   30 to 44 minutes                                             3,110
#   45 to 59 minutes                                             1,540
#   60 minutes and over                                          1,565
#
#                                                    Bathurst Manor  \
# Characteristic
# Total - Commuting duration for the employed lab...          7,355
#   Less than 15 minutes                                        850
#   15 to 29 minutes                                          1,750
#   30 to 44 minutes                                          2,120
#   45 to 59 minutes                                          1,465
#   60 minutes and over                                       1,180
#
#                                                    Bay Street Corridor  \
# Characteristic
# Total - Commuting duration for the employed lab...              11,815
#   Less than 15 minutes                                           3,175
#   15 to 29 minutes                                               4,900
#   30 to 44 minutes                                               2,200
#   45 to 59 minutes                                                 690
#   60 minutes and over                                              855
#
#                                                    Bayview Village  \
# Characteristic
# Total - Commuting duration for the employed lab...           9,820
#   Less than 15 minutes                                         860
#   15 to 29 minutes                                           2,560
#   30 to 44 minutes                                           3,065
#   45 to 59 minutes                                           1,865
#   60 minutes and over                                        1,480
#
#                                                    Bayview Woods-Steeles  \
# Characteristic
# Total - Commuting duration for the employed lab...                 4,965
#   Less than 15 minutes                                               480
#   15 to 29 minutes                                                 1,385
#   30 to 44 minutes                                                 1,320
#   45 to 59 minutes                                                   770
#   60 minutes and over                                              1,000
#
#                                                    Bedford Park-Nortown  \
# Characteristic
# Total - Commuting duration for the employed lab...                9,515
#   Less than 15 minutes                                            1,560
#   15 to 29 minutes                                                3,060
#   30 to 44 minutes                                                2,995
#   45 to 59 minutes                                                1,200
#   60 minutes and over                                               725
#
#                                                           ...          \
# Characteristic                                            ...
# Total - Commuting duration for the employed lab...        ...
#   Less than 15 minutes                                    ...
#   15 to 29 minutes                                        ...
#   30 to 44 minutes                                        ...
#   45 to 59 minutes                                        ...
#   60 minutes and over                                     ...
#
#                                                    Willowdale West  \
# Characteristic
# Total - Commuting duration for the employed lab...           6,890
#   Less than 15 minutes                                         680
#   15 to 29 minutes                                           1,680
#   30 to 44 minutes                                           2,200
#   45 to 59 minutes                                           1,290
#   60 minutes and over                                        1,050
#
#                                                    Willowridge-Martingrove-Richview  \
# Characteristic
# Total - Commuting duration for the employed lab...                            9,365
#   Less than 15 minutes                                                        1,155
#   15 to 29 minutes                                                            3,165
#   30 to 44 minutes                                                            2,320
#   45 to 59 minutes                                                            1,170
#   60 minutes and over                                                         1,545
#
#                                                     Woburn Woodbine Corridor  \
# Characteristic
# Total - Commuting duration for the employed lab...  21,595             5,965
#   Less than 15 minutes                               2,740               530
#   15 to 29 minutes                                   5,360             1,450
#   30 to 44 minutes                                   5,280             2,145
#   45 to 59 minutes                                   2,895             1,095
#   60 minutes and over                                5,320               735
#
#                                                    Woodbine-Lumsden Wychwood  \
# Characteristic
# Total - Commuting duration for the employed lab...            4,095    6,590
#   Less than 15 minutes                                          370      585
#   15 to 29 minutes                                              900    2,020
#   30 to 44 minutes                                            1,420    2,355
#   45 to 59 minutes                                              915      915
#   60 minutes and over                                           495      720
#
#                                                    Yonge-Eglinton  \
# Characteristic
# Total - Commuting duration for the employed lab...          5,935
#   Less than 15 minutes                                        695
#   15 to 29 minutes                                          1,765
#   30 to 44 minutes                                          2,215
#   45 to 59 minutes                                            795
#   60 minutes and over                                         470
#
#                                                    Yonge-St.Clair  \
# Characteristic
# Total - Commuting duration for the employed lab...          6,350
#   Less than 15 minutes                                        780
#   15 to 29 minutes                                          2,265
#   30 to 44 minutes                                          2,195
#   45 to 59 minutes                                            630
#   60 minutes and over                                         460
#
#                                                    York University Heights  \
# Characteristic
# Total - Commuting duration for the employed lab...                  12,790
#   Less than 15 minutes                                               1,365
#   15 to 29 minutes                                                   3,280
#   30 to 44 minutes                                                   3,430
#   45 to 59 minutes                                                   1,605
#   60 minutes and over                                                3,095
#
#                                                    Yorkdale-Glen Park
# Characteristic
# Total - Commuting duration for the employed lab...              6,420
#   Less than 15 minutes                                            850
#   15 to 29 minutes                                              1,770
#   30 to 44 minutes                                              2,170
#   45 to 59 minutes                                                845
#   60 minutes and over                                             805
#
# [6 rows x 140 columns]

# %% [markdown]
# From this dataset we can see the time ranges in which people are making their commutes. We assuming that people which commuting duration in ranges under 15 minutes and over 60 minutes do not require our services. Therefore we will select the next categories of people which may want to shortcut their commute time:
#
# * 15 to 29 minutes
# * 30 to 44 minutes
# * 45 to 59 minutes
#
# After we are going to find top 10 neigborhoods where these methods dominate among the people

# %%
demo_cdur = demo_cdur[2:5]
demo_cdur_t = demo_cdur.T

arr = list(demo_cdur_t)
for item in arr:
    demo_cdur_t[item] = demo_cdur_t[item].str.replace(',', '')
    demo_cdur_t[item] = demo_cdur_t[item].astype(int) 

demo_cdur_t['Total'] = demo_cdur_t.sum(axis = 1)
demo_cdur_t = demo_cdur_t.sort_values(by=['Total'], ascending=False)
demo_cdur_t = demo_cdur_t.head(10)

demo_cdur_t
# Out:
# Characteristic                         15 to 29 minutes    30 to 44 minutes  \
# Waterfront Communities-The Island                 18250                9955
# Niagara                                            7395                7030
# Willowdale East                                    5430                7290
# Islington-City Centre West                         5935                5795
# Dovercourt-Wallace Emerson-Junction                5335                6665
# Rouge                                              5120                5145
# Woburn                                             5360                5280
# Mount Pleasant West                                4655                6380
# Mimico (includes Humber Bay Shores)                4330                5620
# Church-Yonge Corridor                              7310                4060
#
# Characteristic                         45 to 59 minutes  Total
# Waterfront Communities-The Island                  3320  31525
# Niagara                                            2530  16955
# Willowdale East                                    4175  16895
# Islington-City Centre West                         4265  15995
# Dovercourt-Wallace Emerson-Junction                3055  15055
# Rouge                                              3335  13600
# Woburn                                             2895  13535
# Mount Pleasant West                                2295  13330
# Mimico (includes Humber Bay Shores)                3185  13135
# Church-Yonge Corridor                              1445  12815

# %% [markdown]
# ### 4.3 Theft Security

# %% [markdown]
# #### 4.3.1 Theft reported incidents

# %%
theft.head(10)
# Out:
#            X          Y                Neighbourhood        Primary_Offence
# 0 -79.426674  43.641228          South Parkdale (85)                    B&E
# 1 -79.382637  43.652973     Bay Street Corridor (76)            THEFT UNDER
# 2 -79.313347  43.674377       Woodbine Corridor (64)            THEFT UNDER
# 3 -79.396164  43.653347    Kensington-Chinatown (78)            THEFT UNDER
# 4 -79.381584  43.657909   Church-Yonge Corridor (75)            THEFT UNDER
# 5 -79.389504  43.669670                   Annex (95)            THEFT UNDER
# 6 -79.445328  43.676571  Corso Italia-Davenport (92)  THEFT UNDER - BICYCLE
# 7 -79.356949  43.683933         Broadview North (57)  THEFT UNDER - BICYCLE
# 8 -79.320396  43.672669       Greenwood-Coxwell (65)  THEFT UNDER - BICYCLE
# 9 -79.385048  43.666065   Church-Yonge Corridor (75)  THEFT UNDER - BICYCLE

# %% [markdown]
# Let's count the overall number of the thefts happen in the Toronto by the neigborhoods and select top 10, where the thefts number were minimum.

# %%
theft = theft['Neighbourhood'].value_counts(sort=True, ascending=True).rename_axis('Neighbourhood').reset_index(name='Incidents')
theft = theft.head(10)
theft
# Out:
#                    Neighbourhood  Incidents
# 0             Pleasant View (46)          5
# 1            Rexdale-Kipling (4)          6
# 2     Bayview Woods-Steeles (49)          7
# 3                    Rustic (28)          7
# 4                Maple Leaf (29)          7
# 5  Beechborough-Greenbrook (112)          7
# 6                  Ionview (125)          8
# 7      Pelmo Park-Humberlea (23)          8
# 8          Victoria Village (43)          8
# 9                Humbermede (22)          9

# %% [markdown]
# #### 4.3.2 Bikes which are more likely to be stolen

# %%
thief_taste.head(10)
# Out:
#          Bike_Make       Bike_Model Bike_Type Bike_Colour Cost_of_Bike
# 0  FJ               ROUBAIX 3.0            RC      BLU            1400
# 1  OT               DIADORA                RG      BLU             500
# 2  OT               NAVIGATOR SF24         EL      RED             750
# 3  OT               2015VITA STEPTH        RG      PLE             600
# 4  GI               ESCAPE                 RG      BLU          778.57
# 5  OT               SPEED UNO (KAC0        FO      BLK             400
# 6  RM                           NaN        RG      SIL             600
# 7  KO               BLAST                  MT      ONG            1200
# 8  KO               DAWG                   MT      OTH            2000
# 9  GI               16 ESCAPE 1 L          MT      BLK             769

# %% [markdown]
# To determine which bikes are most likely to be stolen let's first look at the theft statistics by the bike's vendor and the most stolen by the vendor first

# %%
vendor = thief_taste['Bike_Make'].value_counts(sort=True, ascending=False).rename_axis('Vendor').reset_index(name='Count')
vendor = vendor.head(1)
vendor
# Out:
#             Vendor  Count
# 0  OT                2399

# %% [markdown]
# After determining the top vendors we can find which models thiefs more like to steal

# %%
arr = vendor.Vendor.unique()
models = thief_taste.loc[thief_taste['Bike_Make'] == arr[0]]
models = models['Bike_Model'].value_counts(sort=True, ascending=False).rename_axis('Model').reset_index(name='Count')
models = models.head(10)
models
# Out:
#              Model  Count
# 0  MILANO              19
# 1  SIRRUS              19
# 2  HARDROCK            17
# 3  ALLEZ               16
# 4  CLASSICO            12
# 5  VITA                11
# 6  STOCKHOLM           10
# 7  CROSSTRAIL          10
# 8  VENTURA SPORT       10
# 9  MODENA               9

# %% [markdown]
# Another parameter that allow us to define bikes which more likely will be stolen is the color. Let's find top 3 colors that thiefs in Toronto like.

# %%
colors = thief_taste['Bike_Colour'].value_counts(sort=True, ascending=False).rename_axis('Color').reset_index(name='Count')
colors = colors.head(3)
colors
# Out:
#     Color  Count
# 0  BLK      3691
# 1  BLU      1271
# 2  WHI      1150

# %% [markdown]
# ## 5. Results and Conclusion <a name="results"></a>

# %%
stats = pd.DataFrame()
stats['Safety'] = safety['Neighbourhood'].str.rstrip(')(1234567890')
stats['Security'] = theft['Neighbourhood'].str.rstrip(')(1234567890')
stats['Age'] = demo_age_t.index.values
stats['Commuting destination'] = demo_cdes_t.index.values
stats['Main Commute Mode'] = commute_t.index.values
stats['Commute Time'] = demo_cdur_t.index.values

stats
# Out:
#                                Safety                  Security  \
# 0            Palmerston-Little Italy             Pleasant View
# 1       Agincourt South-Malvern West           Rexdale-Kipling
# 2  Waterfront Communities-The Island     Bayview Woods-Steeles
# 3                           Wychwood                    Rustic
# 4                    Little Portugal                Maple Leaf
# 5                Mount Pleasant East   Beechborough-Greenbrook
# 6              Birchcliffe-Cliffside                   Ionview
# 7                        The Beaches      Pelmo Park-Humberlea
# 8                        New Toronto          Victoria Village
# 9                          Casa Loma                Humbermede
#
#                                    Age                Commuting destination  \
# 0    Waterfront Communities-The Island    Waterfront Communities-The Island
# 1                      Willowdale East                              Niagara
# 2                               Woburn                Church-Yonge Corridor
# 3                              Niagara                      Willowdale East
# 4           Islington-City Centre West                               Woburn
# 5                                Rouge                                Rouge
# 6                              Malvern  Dovercourt-Wallace Emerson-Junction
# 7                Church-Yonge Corridor                  Mount Pleasant West
# 8  Dovercourt-Wallace Emerson-Junction           Islington-City Centre West
# 9                           L'Amoreaux                              Malvern
#
#                      Main Commute Mode                         Commute Time
# 0    Waterfront Communities-The Island    Waterfront Communities-The Island
# 1                Church-Yonge Corridor                              Niagara
# 2                              Niagara                      Willowdale East
# 3                  Mount Pleasant West           Islington-City Centre West
# 4                      Willowdale East  Dovercourt-Wallace Emerson-Junction
# 5  Dovercourt-Wallace Emerson-Junction                                Rouge
# 6                                Annex                               Woburn
# 7                  Bay Street Corridor                  Mount Pleasant West
# 8           Islington-City Centre West  Mimico (includes Humber Bay Shores)
# 9                               Woburn                Church-Yonge Corridor

# %% [markdown]
# We have analyzed the open datasets provided by the offical authorities of the city of Torronto. Therefore there is not doubt in authenticity of the information. Of course the data provided is not the most "fresh" one, but it provided statistics collected for few last years. By my personal thought it at least reflecting the trends of the last years, therefore it should valid for today as well.
#
# In the final stats dataframe I untited the rating of top neigborhoods by the corresponding parameters. We can definetely say that the leader in the most of categories **Waterfront Communities-The Island** district. If someone wanted to start their bike sharing buisness - it's definetely the place where he should start to place his bike stations
#
# By analysing the theif tastes we found that thiefs most likely to steal **black, white and blue** bikes and bikes made by vendor **OT** with the next model preferencies: **MILANO, SIRRUS, HARDROCK, ALLEZ, CLASSICO, VITA, STOCKHOLM, CROSSTRAIL, VENTURA, SPORT,	MODENA**. I would recoment to the bike sharing owner in toronto to not buy these bikes models and be careful with the bikes in these colours.
